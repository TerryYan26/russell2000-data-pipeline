# %% [markdown]
# # ✅ Databento + SQLite 示例 Notebook
# 完整流程，使用 `databento` 从 Nasdaq（XNAS）获取历史 OHLCV 数据，保存到 SQLite，并避免 KeyError 错误。

# %%
# !pip install databento pandas
# Out:
# Requirement already satisfied: databento in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (0.58.0)
# Requirement already satisfied: pandas in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (2.3.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from databento) (3.12.14)
# Requirement already satisfied: databento-dbn<0.37.0,>=0.36.2 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from databento) (0.36.2)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from databento) (2.0.2)
# Requirement already satisfied: pip-system-certs>=4.0 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from databento) (4.0)
# Requirement already satisfied: pyarrow>=13.0.0 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from databento) (20.0.0)
# Requirement already satisfied: requests>=2.25.1 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from databento) (2.32.4)
# Requirement already satisfied: zstandard>=0.21.0 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from databento) (0.23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\16262\appdata\roaming\python\python39\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->databento) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->databento) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->databento) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->databento) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->databento) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->databento) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->databento) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->databento) (1.20.1)
# Requirement already satisfied: wrapt>=1.10.4 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from pip-system-certs>=4.0->databento) (1.17.2)
# Requirement already satisfied: six>=1.5 in c:\users\16262\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from requests>=2.25.1->databento) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from requests>=2.25.1->databento) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from requests>=2.25.1->databento) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\16262\documents\github\ece176hw1\.conda\lib\site-packages (from requests>=2.25.1->databento) (2025.7.14)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\16262\appdata\roaming\python\python39\site-packages (from aiosignal>=1.4.0->aiohttp<4.0.0,>=3.8.3->databento) (4.10.0)

# %%
import databento as db
import sqlite3
import pandas as pd

# ✅ Your Databento API Key
API_KEY = "db-HJbwXgmEyHqvLp8PLsCdCHmg4KfKp"

# ✅ SQLite database file
DB_FILE = ' Russell 2000.db'

# ✅ Initialize Databento Historical client
client = db.Historical(API_KEY)

def init_db():
    """
    Initialize the SQLite database and create the market_data table if it doesn't exist.
    """
    conn = sqlite3.connect(DB_FILE)
    cursor = conn.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS market_data (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            symbol TEXT,
            ts_event TEXT,
            open REAL,
            high REAL,
            low REAL,
            close REAL,
            volume REAL
        )
    ''')
    conn.commit()
    cursor.close()
    conn.close()
    print("✅ SQLite table has been created successfully")

# %%
def fetch_historical_data(symbol, start, end):
    """
    Fetch historical OHLCV data for a given symbol and time range from Databento.
    """
    try:
        data = client.timeseries.get_range(
            dataset="XNAS.ITCH",    # Nasdaq ITCH dataset
            schema="ohlcv-1m",      # 1-minute OHLCV schema
            symbols=symbol,
            start=start,
            end=end
        )
        df = data.to_df()
        print(df.columns)  # Print columns to verify schema
        print(df.head())   # Print first few rows for quick preview
        return df
    except Exception as e:
        print(f"⚠️ Failed to fetch data for {symbol}: {e}")
        return pd.DataFrame()

# %%
def save_data_sqlite(symbol, df):
    """
    Save the historical data DataFrame into the SQLite database.
    Each row will be inserted with symbol, timestamp, and OHLCV values.
    """
    conn = sqlite3.connect(DB_FILE)
    cursor = conn.cursor()
    for _, row in df.iterrows():
        cursor.execute(
            '''
            INSERT INTO market_data (symbol, ts_event, open, high, low, close, volume)
            VALUES (?, ?, ?, ?, ?, ?, ?)
            ''',
            (
                symbol,
                str(row.name),  # ✅ Use DataFrame index as the timestamp
                row["open"],
                row["high"],
                row["low"],
                row["close"],
                row["volume"]
            )
        )
    conn.commit()
    cursor.close()
    conn.close()

# %%
def main():
    """
    Main execution function.
    Initializes the database, fetches historical data for each symbol, 
    and saves it into the SQLite database.
    """
    init_db()
    symbols = ["IWM"]  # Use IWM as the Russell 2000 Index representative
    for symbol in symbols:
        print(f"🔎 Processing: {symbol}")
        df = fetch_historical_data(symbol, start="2023-07-07", end="2023-07-11")
        if not df.empty:
            save_data_sqlite(symbol, df)
            print(f"✅ {symbol} data saved successfully.")
        else:
            print(f"❌ No data found for {symbol}.")
    print("🎉 All tasks completed.")

main()
# Out:
# ✅ SQLite table has been created successfully
# 🔎 Processing: IWM
# Index(['rtype', 'publisher_id', 'instrument_id', 'open', 'high', 'low',
#        'close', 'volume', 'symbol'],
#       dtype='object')
#                            rtype  publisher_id  instrument_id    open    high  \
# ts_event
# 2023-07-07 08:00:00+00:00     33             2           5597  182.11  182.11
# 2023-07-07 08:03:00+00:00     33             2           5597  181.97  181.97
# 2023-07-07 08:04:00+00:00     33             2           5597  182.05  182.05
# 2023-07-07 08:09:00+00:00     33             2           5597  182.00  182.00
# 2023-07-07 08:18:00+00:00     33             2           5597  182.35  182.35
#
#                               low   close  volume symbol
# ts_event
# 2023-07-07 08:00:00+00:00  182.11  182.11     100    IWM
# 2023-07-07 08:03:00+00:00  181.97  181.97      75    IWM
# 2023-07-07 08:04:00+00:00  182.05  182.05       5    IWM
# 2023-07-07 08:09:00+00:00  182.00  182.00       3    IWM
# 2023-07-07 08:18:00+00:00  182.35  182.35      25    IWM
# ✅ IWM data saved successfully.
# 🎉 All tasks completed.

# %%
def query_data():
    conn = sqlite3.connect(DB_FILE)
    df = pd.read_sql("SELECT * FROM market_data ORDER BY ts_event DESC LIMIT 10", conn)
    conn.close()
    return df

query_data()
# Out:
#      id symbol                   ts_event    open    high     low   close  \
# 0  1137    IWM  2023-07-10 23:58:00+00:00  188.27  188.33  188.27  188.33
# 1  1136    IWM  2023-07-10 23:57:00+00:00  188.28  188.29  188.27  188.27
# 2  1135    IWM  2023-07-10 23:49:00+00:00  188.24  188.26  188.24  188.26
# 3  1134    IWM  2023-07-10 23:46:00+00:00  188.23  188.23  188.23  188.23
# 4  1133    IWM  2023-07-10 23:45:00+00:00  188.20  188.20  188.20  188.20
# 5  1132    IWM  2023-07-10 23:42:00+00:00  188.16  188.16  188.16  188.16
# 6  1131    IWM  2023-07-10 23:34:00+00:00  188.14  188.14  188.14  188.14
# 7  1130    IWM  2023-07-10 23:30:00+00:00  188.24  188.24  188.24  188.24
# 8  1129    IWM  2023-07-10 23:29:00+00:00  188.23  188.23  188.23  188.23
# 9  1128    IWM  2023-07-10 23:10:00+00:00  188.24  188.24  188.24  188.24
#
#    volume
# 0  1923.0
# 1   940.0
# 2    10.0
# 3   344.0
# 4     5.0
# 5    80.0
# 6    10.0
# 7   109.0
# 8   263.0
# 9    50.0
